# %%
import plotly
import plotly.plotly as py
import plotly.graph_objs as go
import plotly.figure_factory as FF
import matplotlib.pyplot as pyplot
from pandas import DataFrame
from datetime import datetime
# %matplotlib inline

import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv('bigout.csv')
df2 = DataFrame(df1)

# %%
df1['dateindex'] = pd.to_datetime(df1['dateindex'])

# %%
df1.index = df1['dateindex']
del df1['dateindex']
df1
# Out:
#                    otherhuman
# dateindex
# 2010-06-30    Philippe Reines
# 2010-06-17      Richard Verma
# 2010-06-16      Lauren Jiloty
# 2010-06-27       Cheryl Mills
# 2010-06-30      Jake Sullivan
# 2010-06-16  Sidney Blumenthal
# 2010-06-24       Cheryl Mills
# 2010-07-01      Jake Sullivan
# 2010-06-19      Jake Sullivan
# 2010-06-27        Huma Abedin
# 2010-06-20      Jake Sullivan
# 2010-06-24    Philippe Reines
# 2010-06-26  Sidney Blumenthal
# 2010-06-22       Robert Russo
# 2010-06-22      Lauren Jiloty
# 2010-06-28      Jake Sullivan
# 2010-06-25       Lona Valmoro
# 2010-06-28       Cheryl Mills
# 2010-06-21      Monica Hanley
# 2010-06-26       Lona Valmoro
# 2010-06-30       Lona Valmoro
# 2010-06-22      Monica Hanley
# 2010-06-29      Monica Hanley
# 2001-01-01  Sidney Blumenthal
# 2010-06-26      Lauren Jiloty
# 2010-06-30       Cheryl Mills
# 2010-06-22      Lauren Jiloty
# 2010-06-26      Lauren Jiloty
# 2010-06-20      Jake Sullivan
# 2010-06-25       Robert Russo
# ...                       ...
# 2010-12-03       Cheryl Mills
# 2010-12-02       Cheryl Mills
# 2010-12-02        Huma Abedin
# 2010-12-02        Huma Abedin
# 2010-12-02      Jake Sullivan
# 2010-12-04    Jeffrey Feltman
# 2010-12-04  Sidney Blumenthal
# 2010-12-07       Cheryl Mills
# 2010-12-07        Huma Abedin
# 2010-12-05      Michael Fuchs
# 2010-12-04  Sidney Blumenthal
# 2010-12-02        Huma Abedin
# 2010-12-02       Cheryl Mills
# 2010-12-01      Richard Verma
# 2010-12-01        Huma Abedin
# 2010-11-30        Huma Abedin
# 2010-12-05      Jake Sullivan
# 2010-12-04      Lauren Jiloty
# 2010-12-03  Sidney Blumenthal
# 2010-12-02       Cheryl Mills
# 2010-12-02        Huma Abedin
# 2010-12-02        Huma Abedin
# 2010-12-02      Jake Sullivan
# 2010-11-30        Huma Abedin
# 2010-12-07    Philippe Reines
# 2010-12-06      Lauren Jiloty
# 2010-12-05    Melanne Verveer
# 2010-12-02        Huma Abedin
# 2010-12-01        Huma Abedin
# 2010-12-06  Sidney Blumenthal
#
# [989 rows x 1 columns]

# %%
# dfmon = df1['2010-1']

for i in range(13):
    try:
        dfmon = df1[('2010-'+str(i))]
        # print (dfmon)
        print (i)
        newdf = dfmon.groupby('otherhuman')['otherhuman'].count().plot.bar()
        print (newdf)
        # newdf.index.name = 'Month' + str(i)
    except:
        zero = True
# Out:
# 1
# AxesSubplot(0.125,0.125;0.775x0.755)
# 2
# AxesSubplot(0.125,0.125;0.775x0.755)
# 3
# AxesSubplot(0.125,0.125;0.775x0.755)
# 4
# AxesSubplot(0.125,0.125;0.775x0.755)
# 5
# AxesSubplot(0.125,0.125;0.775x0.755)
# 6
# AxesSubplot(0.125,0.125;0.775x0.755)
# 7
# AxesSubplot(0.125,0.125;0.775x0.755)
# 8
# 9
# 10
# 11
# AxesSubplot(0.125,0.125;0.775x0.755)
# 12
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
dfmon
# Out:
#                       otherhuman
# dateindex
# 2010-01-31         Lauren Jiloty
# 2010-01-31         Lauren Jiloty
# 2010-01-31       Lissa Muscatine
# 2010-01-30         Jake Sullivan
# 2010-01-30     Sidney Blumenthal
# 2010-01-27         Judith McHale
# 2010-01-27       Hillary Clinton
# 2010-01-27       Hillary Clinton
# 2010-01-25          Cheryl Mills
# 2010-01-31         Lauren Jiloty
# 2010-01-31         Lauren Jiloty
# 2010-01-30          Cheryl Mills
# 2010-01-30          Cheryl Mills
# 2010-01-25         Jake Sullivan
# 2010-01-24         Lauren Jiloty
# 2010-01-31         Lauren Jiloty
# 2010-01-31       Lissa Muscatine
# 2010-01-31         Judith McHale
# 2010-01-29          Cheryl Mills
# 2010-01-28          Cheryl Mills
# 2010-01-28             Nora Toiv
# 2010-01-28  Anne-Marie Slaughter
# 2010-01-25         Doug Hattaway
# 2010-01-24         Lauren Jiloty
# 2010-01-31         Jake Sullivan
# 2010-01-30  Anne-Marie Slaughter
# 2010-01-24         Jake Sullivan
# 2010-01-31         Jake Sullivan
# 2010-01-30         Judith McHale
# 2010-01-27         Jake Sullivan
# ...                          ...
# 2010-01-15          Cheryl Mills
# 2010-01-13          Cheryl Mills
# 2010-01-12       Kris Balderston
# 2010-01-10         Doug Hattaway
# 2010-01-07          Cheryl Mills
# 2010-01-15          Cheryl Mills
# 2010-01-09         Lauren Jiloty
# 2010-01-15          Cheryl Mills
# 2010-01-15          Cheryl Mills
# 2010-01-14          Cheryl Mills
# 2010-01-14         Lauren Jiloty
# 2010-01-15          Cheryl Mills
# 2010-01-14         Lauren Jiloty
# 2010-01-11          Robert Russo
# 2010-01-11          Robert Russo
# 2010-01-11         Lauren Jiloty
# 2010-01-10       Kris Balderston
# 2010-01-15          Lona Valmoro
# 2010-01-12         Jake Sullivan
# 2010-01-11          Cheryl Mills
# 2010-01-10       Kris Balderston
# 2010-01-10       Kris Balderston
# 2010-01-09          Robert Russo
# 2010-01-07          Cheryl Mills
# 2010-01-15          Cheryl Mills
# 2010-01-15          Lona Valmoro
# 2010-01-14         Lauren Jiloty
# 2010-01-11           Huma Abedin
# 2010-01-11       Kris Balderston
# 2010-01-11       Kris Balderston
#
# [195 rows x 1 columns]

# %%
print (dfmon.groupby('otherhuman')['otherhuman'].count().plot.bar())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print (df2)
# Out:
# otherhuman
# Anne-Marie Slaughter     4
# Arturo Valenzuela        1
# Cheryl Mills            42
# Doug Hattaway            2
# Ellen Tauscher           1
# Esther Brimmer           2
# Harold Hongju Koh        2
# Hillary Clinton          2
# Huma Abedin             12
# Jacob Lew                2
# Jake Sullivan           26
# James Steinberg          1
# Judith McHale            4
# KellyC@state.gov         2
# Kris Balderston          6
# Lauren Jiloty           31
# Lissa Muscatine          9
# Lona Valmoro             7
# Maria Otero              4
# Melanne Verveer          1
# Michael Fuchs            1
# Monica Hanley            1
# Nora Toiv                6
# Philip Gordon            2
# Philippe Reines          2
# Rajiv Shah               1
# Richard Verma            2
# Robert Russo             5
# Sidney Blumenthal        9
# Strobe Talbott           2
# Todd Stern               2
# Tomicah Tillemann        1
# Name: otherhuman, dtype: int64

# %%
df2.plot.bar()

# %%
df2 = pd.read_csv('wikivalout.csv', header=None, index_col=0)
print (df2)
# Out:
#                        1
# 0
# Jake Sullivan         17
# Lauren Jiloty         16
# Cheryl Mills          10
# Huma Abedin           10
# Monica Hanley          6
# Lona Valmoro           6
# Anne-Marie Slaughter   3
# Sidney Blumenthal      3
# Philippe Reines        3
# Robert Russo           2
# Richard Verma          2
# Cherie Blair           1
# Strobe Talbott         1

# %%
df2.plot.bar()

# %%
df2.plot.bar()
