# %%
import matplotlib.pyplot as pyplot
from pandas import DataFrame
from datetime import datetime
# %matplotlib inline

import numpy as np
import pandas as pd

# %%
df1 = pd.read_csv('bigout.csv')
df2 = DataFrame(df1)

# %%
df1['dateindex'] = pd.to_datetime(df1['dateindex'])

# %%
df1.index = df1['dateindex']
del df1['dateindex']
df1
# Out:
#                       otherhuman
# dateindex
# 2010-12-05         Jake Sullivan
# 2010-12-05           Huma Abedin
# 2010-12-04           Huma Abedin
# 2010-12-04           Huma Abedin
# 2010-12-02         Jake Sullivan
# 2010-12-02           Huma Abedin
# 2010-12-02          Cheryl Mills
# 2010-12-01           Huma Abedin
# 2010-12-07  Anne-Marie Slaughter
# 2010-12-06       Melanne Verveer
# 2010-12-06         Jake Sullivan
# 2010-12-05         Lauren Jiloty
# 2010-12-04         Jake Sullivan
# 2010-12-02          Cheryl Mills
# 2010-12-02           Huma Abedin
# 2010-12-01     Sidney Blumenthal
# 2010-11-28         Jake Sullivan
# 2010-11-28           Huma Abedin
# 2010-11-28           Huma Abedin
# 2010-11-30          Cheryl Mills
# 2010-11-29     Sidney Blumenthal
# 2010-11-28            Todd Stern
# 2010-11-28          Cheryl Mills
# 2010-11-28         Jake Sullivan
# 2010-11-29           Huma Abedin
# 2010-11-28         Jake Sullivan
# 2010-11-28         Jake Sullivan
# 2010-11-28           Huma Abedin
# 2010-11-28           Huma Abedin
# 2010-11-27       Philippe Reines
# ...                          ...
# 2009-06-28     Sidney Blumenthal
# 2009-06-08          Cheryl Mills
# 2009-06-13           Huma Abedin
# 2009-06-13           Huma Abedin
# 2009-06-13           Huma Abedin
# 2009-06-12         Jake Sullivan
# 2009-05-28          Cheryl Mills
# 2009-05-25          Cheryl Mills
# 2009-05-24          Cheryl Mills
# 2009-05-22          Cheryl Mills
# 2009-03-20              philippe
# 2009-09-07          Neera Tanden
# 2009-09-08          Neera Tanden
# 2009-09-03          Neera Tanden
# 2009-09-01          Neera Tanden
# 2009-11-25         William Burns
# 2009-11-29     Sidney Blumenthal
# 2009-11-12     Sidney Blumenthal
# 2009-11-12     Sidney Blumenthal
# 2009-10-27     Sidney Blumenthal
# 2009-09-29     Sidney Blumenthal
# 2009-09-22       Kris Balderston
# 2009-06-24          Cheryl Mills
# 2009-06-05          Cheryl Mills
# 2009-06-26         Jake Sullivan
# 2009-06-25          Cheryl Mills
# 2009-06-13           Huma Abedin
# 2009-06-13           Huma Abedin
# 2009-06-12         Jake Sullivan
# 2009-06-08          Cheryl Mills
#
# [6279 rows x 1 columns]

# %%
dfmon = df1['2010-1']
print (dfmon.groupby('otherhuman')['otherhuman'].count().plot.bar())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
dfmon = df1['2010-2']
print (dfmon.groupby('otherhuman')['otherhuman'].count().plot.bar())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
dfmon = df1['2010-3']
print (dfmon.groupby('otherhuman')['otherhuman'].count().plot.bar())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
dfmon = df1['2010-4']
print (dfmon.groupby('otherhuman')['otherhuman'].count().plot.bar())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
dfmon = df1['2010-5']
print (dfmon.groupby('otherhuman')['otherhuman'].count().plot.bar())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
dfmon = df1['2010-6']
print (dfmon.groupby('otherhuman')['otherhuman'].count().plot.bar())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
dfmon = df1['2012-1']
print (dfmon.groupby('otherhuman')['otherhuman'].count().plot.bar())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
dfmon = df1['2012-2']
print (dfmon.groupby('otherhuman')['otherhuman'].count().plot.bar())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
dfmon = df1['2012-3']
print (dfmon.groupby('otherhuman')['otherhuman'].count().plot.bar())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
dfmon = df1['2012-4']
print (dfmon.groupby('otherhuman')['otherhuman'].count().plot.bar())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
dfmon = df1['2012-5']
print (dfmon.groupby('otherhuman')['otherhuman'].count().plot.bar())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# # Spike in correspondence with Monica Handley - "Key Hillary Clinton aide repeatedly misplaced sensitive info"

# %%
dfmon = df1['2012-6']
print (dfmon.groupby('otherhuman')['otherhuman'].count().plot.bar())
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
df2 = pd.read_csv('wikivalout.csv', header=None, index_col=0)
print (df2)
# Out:
#                        1
# 0
# Jake Sullivan         17
# Lauren Jiloty         16
# Cheryl Mills          10
# Huma Abedin           10
# Monica Hanley          6
# Lona Valmoro           6
# Anne-Marie Slaughter   3
# Sidney Blumenthal      3
# Philippe Reines        3
# Robert Russo           2
# Richard Verma          2
# Cherie Blair           1
# Strobe Talbott         1

# %%
df2.plot.bar()

# %%
for i in range(2):
    try:
        dfmon = df1[('2010-'+str(i))]
        # print (dfmon)
        print (i)
        newdf = dfmon.groupby('otherhuman')['otherhuman'].count().plot.bar()
        print (newdf)
        # newdf.index.name = 'Month' + str(i)
    except:
        zero = True
# Out:
# 1
# AxesSubplot(0.125,0.125;0.775x0.755)
